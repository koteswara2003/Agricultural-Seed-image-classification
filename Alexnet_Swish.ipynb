# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, LearningRateScheduler
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# **AlexNet Architecture**
def build_alexnet(input_shape, num_classes):
    model = Sequential([
        Conv2D(96, (11, 11), strides=4, activation=tf.nn.swish, input_shape=input_shape),
        MaxPooling2D((3, 3), strides=2),
        BatchNormalization(),
        Dropout(0.6),  # Increased dropout rate
        Conv2D(256, (5, 5), padding='same', activation=tf.nn.swish),
        MaxPooling2D((3, 3), strides=2),
        BatchNormalization(),
        Dropout(0.6),  # Increased dropout rate
        Conv2D(384, (3, 3), padding='same', activation=tf.nn.swish),
        Conv2D(384, (3, 3), padding='same', activation=tf.nn.swish),
        Conv2D(256, (3, 3), padding='same', activation=tf.nn.swish),
        MaxPooling2D((3, 3), strides=2),
        BatchNormalization(),
        Dropout(0.6),  # Increased dropout rate
        Flatten(),
        Dense(4096, activation=tf.nn.swish),
        Dropout(0.6),  # Increased dropout rate
        Dense(4096, activation=tf.nn.swish),
        Dropout(0.6),  # Increased dropout rate
        Dense(num_classes, activation='softmax')  # Adjust based on your dataset
    ])
    optimizer = Adam(learning_rate=0.0001)  # Lower learning rate
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

dataset_dir = 'C:/Users/DELL/OneDrive/Documents/majorProject/seedsBalanced'

# **Data Augmentation**
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,  # Increased rotation range
    width_shift_range=0.2,  # Increased width shift
    height_shift_range=0.2,  # Increased height shift
    shear_range=0.2,  # Increased shear range
    zoom_range=0.2,  # Increased zoom range
    horizontal_flip=True, 
    fill_mode='reflect',
    validation_split=0.2  # Splitting 20% for validation
)

# **Load Dataset**
train_gen = datagen.flow_from_directory(
    dataset_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    dataset_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical',
    subset='validation'
)

# **Build and Train the Model**
num_classes = len(train_gen.class_indices)
alexnet_model = build_alexnet(input_shape=(224, 224, 3), num_classes=num_classes)

# Learning Rate Scheduler
def lr_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.9  # Reduce learning rate by 10% after epoch 10

lr_callback = LearningRateScheduler(lr_scheduler)

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
early_stopping = EarlyStopping(monitor='val_loss', patience=29, restore_best_weights=True)

history = alexnet_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=30,  # Increased number of epochs
    callbacks=[reduce_lr, early_stopping, lr_callback]
)


# **Evaluate the Model**
val_loss, val_accuracy = alexnet_model.evaluate(val_gen)
print(f'Validation Loss: {val_loss}')
print(f'Validation Accuracy: {val_accuracy}')
# Out:
# Found 3134 images belonging to 8 classes.
# Found 778 images belonging to 8 classes.
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 453s 9s/step - accuracy: 0.4261 - loss: 2.0939 - val_accuracy: 0.1247 - val_loss: 3.2696 - learning_rate: 1.0000e-04
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 397s 8s/step - accuracy: 0.8259 - loss: 0.4574 - val_accuracy: 0.1247 - val_loss: 5.4964 - learning_rate: 1.0000e-04
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 440s 9s/step - accuracy: 0.8678 - loss: 0.3696 - val_accuracy: 0.1247 - val_loss: 6.6265 - learning_rate: 1.0000e-04
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 383s 8s/step - accuracy: 0.8963 - loss: 0.2709 - val_accuracy: 0.1247 - val_loss: 7.9554 - learning_rate: 1.0000e-04
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 406s 8s/step - accuracy: 0.9243 - loss: 0.2038 - val_accuracy: 0.2519 - val_loss: 7.7079 - learning_rate: 1.0000e-04
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 439s 9s/step - accuracy: 0.9256 - loss: 0.1988 - val_accuracy: 0.2828 - val_loss: 9.0929 - learning_rate: 1.0000e-04
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 451s 9s/step - accuracy: 0.9413 - loss: 0.1649 - val_accuracy: 0.1260 - val_loss: 14.0959 - learning_rate: 1.0000e-04
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 390s 8s/step - accuracy: 0.9358 - loss: 0.1754 - val_accuracy: 0.3638 - val_loss: 10.0237 - learning_rate: 1.0000e-04
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 455s 9s/step - accuracy: 0.9708 - loss: 0.0938 - val_accuracy: 0.2532 - val_loss: 16.8939 - learning_rate: 1.0000e-04
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 431s 9s/step - accuracy: 0.9452 - loss: 0.1811 - val_accuracy: 0.2494 - val_loss: 10.9173 - learning_rate: 1.0000e-04
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 403s 8s/step - accuracy: 0.9657 - loss: 0.1047 - val_accuracy: 0.4550 - val_loss: 8.3073 - learning_rate: 9.0000e-05
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 420s 8s/step - accuracy: 0.9739 - loss: 0.0873 - val_accuracy: 0.6195 - val_loss: 3.8247 - learning_rate: 8.1000e-05
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 378s 8s/step - accuracy: 0.9669 - loss: 0.0897 - val_accuracy: 0.6414 - val_loss: 5.0945 - learning_rate: 7.2900e-05
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 409s 8s/step - accuracy: 0.9779 - loss: 0.0822 - val_accuracy: 0.6761 - val_loss: 1.4160 - learning_rate: 6.5610e-05
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 423s 9s/step - accuracy: 0.9819 - loss: 0.0558 - val_accuracy: 0.7391 - val_loss: 1.3016 - learning_rate: 5.9049e-05
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 402s 8s/step - accuracy: 0.9798 - loss: 0.0568 - val_accuracy: 0.6144 - val_loss: 1.8556 - learning_rate: 5.3144e-05
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 363s 7s/step - accuracy: 0.9822 - loss: 0.0488 - val_accuracy: 0.6799 - val_loss: 2.8899 - learning_rate: 4.7830e-05
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 358s 7s/step - accuracy: 0.9870 - loss: 0.0317 - val_accuracy: 0.6915 - val_loss: 2.5335 - learning_rate: 4.3047e-05
# Epoch 19/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 363s 7s/step - accuracy: 0.9881 - loss: 0.0305 - val_accuracy: 0.7391 - val_loss: 2.9662 - learning_rate: 3.8742e-05
# Epoch 20/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 418s 9s/step - accuracy: 0.9856 - loss: 0.0358 - val_accuracy: 0.7404 - val_loss: 2.5278 - learning_rate: 3.4868e-05
# Epoch 21/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 425s 9s/step - accuracy: 0.9910 - loss: 0.0399 - val_accuracy: 0.6452 - val_loss: 2.3464 - learning_rate: 3.1381e-05
# Epoch 22/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 408s 8s/step - accuracy: 0.9888 - loss: 0.0386 - val_accuracy: 0.8072 - val_loss: 0.6754 - learning_rate: 2.8243e-05
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 388s 8s/step - accuracy: 0.9891 - loss: 0.0538 - val_accuracy: 0.8445 - val_loss: 0.5501 - learning_rate: 2.5419e-05
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 391s 8s/step - accuracy: 0.9874 - loss: 0.0417 - val_accuracy: 0.8085 - val_loss: 0.8433 - learning_rate: 2.2877e-05
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 377s 8s/step - accuracy: 0.9840 - loss: 0.0442 - val_accuracy: 0.7416 - val_loss: 1.9033 - learning_rate: 2.0589e-05
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 355s 7s/step - accuracy: 0.9915 - loss: 0.0226 - val_accuracy: 0.7224 - val_loss: 1.3645 - learning_rate: 1.8530e-05
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 414s 8s/step - accuracy: 0.9870 - loss: 0.0356 - val_accuracy: 0.7712 - val_loss: 1.1558 - learning_rate: 1.6677e-05
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 400s 8s/step - accuracy: 0.9901 - loss: 0.0257 - val_accuracy: 0.7301 - val_loss: 1.3804 - learning_rate: 1.5009e-05
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 441s 9s/step - accuracy: 0.9906 - loss: 0.0285 - val_accuracy: 0.7391 - val_loss: 2.4994 - learning_rate: 1.3509e-05
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 341s 7s/step - accuracy: 0.9882 - loss: 0.0290 - val_accuracy: 0.7982 - val_loss: 0.8686 - learning_rate: 1.2158e-05
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.8268 - loss: 0.5026
# Validation Loss: 0.5547393560409546
# Validation Accuracy: 0.8200514316558838

# %%
# **Confusion Matrix & Classification Report**
def evaluate_model(model, val_gen):
    y_true = []
    y_pred = []
    
    for i in range(len(val_gen)):
        img_batch, label_batch = val_gen[i]
        preds = model.predict(img_batch)
        y_true.extend(np.argmax(label_batch, axis=1))
        y_pred.extend(np.argmax(preds, axis=1))
    
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=val_gen.class_indices.keys(), yticklabels=val_gen.class_indices.keys())
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()
    
    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=val_gen.class_indices.keys()))

evaluate_model(alexnet_model, val_gen)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 689ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 660ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 751ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 689ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 965ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#         blackgram       1.00      1.00      1.00        97
#          chickpea       0.55      0.98      0.70        97
#              corn       1.00      0.73      0.84       100
#         moongbean       1.00      0.95      0.97        96
#         pintobean       1.00      0.56      0.72        95
#          soyabean       1.00      0.79      0.88       100
#             wheat       0.79      1.00      0.88        96
# white kidney bean       0.70      0.65      0.67        97
#
#          accuracy                           0.83       778
#         macro avg       0.88      0.83      0.83       778
#      weighted avg       0.88      0.83      0.83       778

# %%
# **Plot Training and Validation Accuracy and Loss**
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# **Visualizing Predictions on Validation Data**
fig, axes = plt.subplots(5, 5, figsize=(12, 12))
axes = axes.flatten()

class_labels = list(val_gen.class_indices.keys())  # Get class labels

for i in range(25):
    img_batch, label_batch = next(val_gen)  # Corrected to use next()
    
    img = img_batch[0]  # Extract first image from batch
    label = label_batch[0]  # Extract first label from batch
    
    pred = alexnet_model.predict(np.expand_dims(img, axis=0))  # Predict
    pred_label = class_labels[np.argmax(pred[0])]  # Get predicted class
    true_label = class_labels[np.argmax(label)]  # Get true class
    
    axes[i].imshow(img)  # Display Image
    axes[i].set_title(f"Pred: {pred_label}\nTrue: {true_label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step

# %%
test_loss, test_acc = alexnet_model.evaluate(val_gen)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8287 - loss: 0.5779
# Test Accuracy: 0.8406

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Get the true labels and predicted probabilities
y_true = []
y_probs = []

for i in range(len(val_gen)):
    img_batch, label_batch = val_gen[i]
    preds = alexnet_model.predict(img_batch)
    y_true.extend(label_batch)
    y_probs.extend(preds)

y_true = np.array(y_true)
y_probs = np.array(y_probs)

# Compute ROC curve and AUC for each class
n_classes = y_true.shape[1]
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true[:, i], y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step

# %%
from sklearn.metrics import cohen_kappa_score

# Get predicted and true labels
y_pred_labels = np.argmax(y_probs, axis=1)
y_true_labels = np.argmax(y_true, axis=1)

# Compute Kappa Score
kappa = cohen_kappa_score(y_true_labels, y_pred_labels)
print(f"Cohen's Kappa Score: {kappa:.4f}")
# Out:
# Cohen's Kappa Score: 0.8076

# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load and preprocess a sample image
image_path = "C:/Users/DELL/OneDrive/Documents/majorProject/moongbean sample image.jpg"  # Replace with the actual image path
image = load_img(image_path, target_size=(224, 224))  # Resize to match model input size
image = img_to_array(image) / 255.0  # Normalize
image = np.expand_dims(image, axis=0)  # Add batch dimension

# Make prediction
pred = alexnet_model.predict(image)
predicted_class = np.argmax(pred[0])  # Get class index
class_labels = list(val_gen.class_indices.keys())  # Retrieve class labels
predicted_label = class_labels[predicted_class]

# Display result
print(f"Predicted Class: {predicted_label}")

# Show image with prediction
import matplotlib.pyplot as plt
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
plt.imshow(img)
plt.title(f"Predicted: {predicted_label}")
plt.axis("off")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted Class: moongbean

# %%
# **Compute Accuracy for Each Seed Type**
def compute_classwise_accuracy(model, val_gen):
    y_true = []
    y_pred = []
    
    for i in range(len(val_gen)):
        img_batch, label_batch = val_gen[i]
        preds = model.predict(img_batch)
        y_true.extend(np.argmax(label_batch, axis=1))
        y_pred.extend(np.argmax(preds, axis=1))
    
    report = classification_report(y_true, y_pred, target_names=val_gen.class_indices.keys(), output_dict=True)
    
    print("Class-wise Accuracy:")
    for class_name, metrics in report.items():
        if isinstance(metrics, dict):
            print(f"{class_name}: {metrics['precision'] * 100:.2f}%")

compute_classwise_accuracy(alexnet_model, val_gen)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 305ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Class-wise Accuracy:
# blackgram: 100.00%
# chickpea: 56.21%
# corn: 100.00%
# moongbean: 100.00%
# pintobean: 100.00%
# soyabean: 100.00%
# wheat: 79.34%
# white kidney bean: 75.00%
# macro avg: 88.82%
# weighted avg: 88.87%
